# %%
# %run a1.ipynb

# %%
import ipytest
ipytest.autoconfig()

# %%
# %%ipytest
# #decorate test cells with this magic
# def test_my_func():
#     assert a == 1
# Out:
# .                                                                                            [100%]
# 1 passed in 0.01s
